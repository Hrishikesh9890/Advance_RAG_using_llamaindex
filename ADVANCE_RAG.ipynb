# %%
# %pip install llama-index-llms-openai llama-index-embeddings-openai

# %%
# %pip install llama-index
# %pip install llama-index-core
# %pip install llama-index-embeddings-openai
# %pip install llama-index-postprocessor-flag-embedding-reranker
# %pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# %pip install llama-parse
# %pip install llama-index-vector-stores-faiss
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 62.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 86.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 kB 38.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.5 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/FlagOpen/FlagEmbedding.git to /tmp/pip-req-build-x8hnx_rm
# ...

# %%
# attach to the same event-loop
import nest_asyncio

nest_asyncio.apply()

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio
nest_asyncio.apply()
import os
# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = "llx-rb0HWNRJA8vVP1K0V939YEZplIGDdV5ubASK5Dlg5MgjnDak"

from google.colab import userdata

# Get the OpenAI API key from user data
openai_api_key = userdata.get('OPENAI_API_KEY')

# Set the OpenAI API key in the environment variable
os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings

embed_model = OpenAIEmbedding(model="text-embedding-3-small")
llm = OpenAI(model="gpt-3.5-turbo-0125")

Settings.llm = llm
Settings.embed_model = embed_model

# %%
from llama_parse import LlamaParse

documents = LlamaParse(result_type="markdown").load_data("/content/drive/MyDrive/protocol.pdf")
# Out:
# Started parsing the file under job_id bc118f4c-9b58-4c48-873c-9a6f59d329f7

# %%
print(documents[0].text[:1000] + "...")
# Out:
# ## Protocol Title:
#
# A Phase 1/2 Multicenter Study Evaluating the Safety and Efficacy of KTE-C19 in Subjects with Refractory Aggressive Non-Hodgkin Lymphoma (ZUMA-1)
#
# ## Protocol Number:
#
# KTE-C19-101
#
# ## IND Number:
#
# 016278
#
# ## EudraCT Number:
#
# 2015-005007-86
#
# ## Clinical Study Sponsor:
#
# Kite Pharma, Inc.
#
# 2400 Broadway
#
# Santa Monica, CA 90404
#
# United States of America
#
# ## Key Sponsor Contacts:
#
# |PPD|Clinical Development|
# |---|---|
# |Kite Pharma, Inc.|2 Roundwood Avenue Stockley Park Uxbridge, Middlesex Phone: PPD Email: PPD|
# |Kite Pharma Inc.|2400 Broadway Santa Monica, CA 90404 Phone: PPD Email: PPD|
# |Kite Pharma, Inc.|2400 Broadway Santa Monica, CA 90404 Phone: PPD Email: PPD|
#
# ## Version:
#
# 1.0 (Amendment # 8)
#
# ## Date:
#
# 11 February 2019
#
# Confidentiality Notice
#
# ...

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(
    llm=OpenAI(model="gpt-3.5-turbo-0125"), num_workers=8
)

# %%
nodes = node_parser.get_nodes_from_documents(documents)
# Out:
# 45it [00:00, 17834.61it/s]
#   2%|▏         | 1/45 [00:02<02:00,  2.73s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 482, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 307, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 391, in astructured_predict
#     result = await program.acall(**prompt_args)
# ...

# %%
DB_FAISS_PATH="/content/hrishi"

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
recursive_index = VectorStoreIndex(nodes=base_nodes + objects)
raw_index = VectorStoreIndex.from_documents(documents)

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex, Settings
from llama_parse import LlamaParse
from llama_index.core.node_parser import MarkdownElementNodeParser
from llama_index.vector_stores.faiss import FaissVectorStore
from llama_index.core import StorageContext
import os

# %%
import os.path
from llama_index.vector_stores.faiss import FaissVectorStore
# check if storage already exists
PERSIST_DIR = "./storage"
PERSIST_DIR = "./storage1"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    recursive_index = VectorStoreIndex(nodes=base_nodes + objects)
    #raw_index = VectorStoreIndex.from_documents(documents)
    # store it for later
    recursive_index.storage_context.persist(persist_dir=PERSIST_DIR)
    #raw_index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    recursive_index = load_index_from_storage(storage_context)
    #raw_index = load_index_from_storage(storage_context)

# %%
import os.path
from llama_index.vector_stores.faiss import FaissVectorStore
# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index

    raw_index = VectorStoreIndex.from_documents(documents)
    # store it for later

    raw_index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    raw_index = load_index_from_storage(storage_context)

# %%
from llama_index.postprocessor.flag_embedding_reranker import (
    FlagEmbeddingReranker,
)

reranker = FlagEmbeddingReranker(
    top_n=5,
    model="BAAI/bge-reranker-large",
)

recursive_query_engine = recursive_index.as_query_engine(
    similarity_top_k=15, node_postprocessors=[reranker], verbose=True
)

raw_query_engine = raw_index.as_query_engine(
    similarity_top_k=15, node_postprocessors=[reranker]
)

# %%
print(len(nodes))
# Out:
# 178

# %%
query = "How many phases is the zuma 1 study separated into?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The ZUMA-1 study is separated into three phases.
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The ZUMA-1 study is separated into three phases: Phase 1 study, Phase 2 pivotal study (Cohorts 1 and 2), and Phase 2 safety management study (Cohorts 3, 4, 5, and 6).

# %%
query = "What is the primary objective of the Phase 1 zuma 1 study?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The primary objective of the Phase 1 ZUMA-1 study is to evaluate the safety of axicabtagene ciloleucel regimens in approximately 6 to 24 subjects with diffuse large B-cell lymphoma (DLBCL), primary mediastinal B-cell lymphoma (PMBCL), or transformed follicular lymphoma (TFL).
# Retrieval entering 69dd7190-34b6-49c6-a6c4-fa08934ac6bf: TextNode
# Retrieving from object TextNode with query What is the primary objective of the Phase 1 zuma 1 study?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The primary objective of the Phase 1 ZUMA-1 study is to evaluate the incidence of dose-limiting toxicities (DLT).

# %%
query = "What is the primary endpoint of the phase 2 study"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The primary endpoint of the Phase 2 pivotal study is the objective response rate (CR + PR) per the revised IWG Response Criteria for Malignant Lymphoma, as determined by the study investigators.
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The primary endpoint of the Phase 2 study is the objective response rate (CR + PR) per the revised IWG Response Criteria for Malignant Lymphoma as determined by study investigators.

# %%
query = "What is the primary endpoint of the phase 1 study?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The primary endpoint of the Phase 1 study is the incidence of dose-limiting toxicities (DLT).
# Retrieval entering 82f0bd41-61fe-4ce7-ad43-253f69c63950: TextNode
# Retrieving from object TextNode with query What is the primary endpoint of the phase 1 study?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The primary endpoint of the Phase 1 study is the incidence of adverse events defined as dose-limiting toxicities (DLT).

# %%
query = "How many subjects will be enrolled in cohort 4 phase 2 safety management study?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# Approximately 40 subjects will be enrolled and dosed in Cohort 4 of the Phase 2 Safety Management Study.
# Retrieval entering 219db267-7079-4000-a2ff-b66d2294b851: TextNode
# Retrieving from object TextNode with query How many subjects will be enrolled in cohort 4 phase 2 safety management study?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Approximately 40 subjects will be enrolled in Cohort 4 of the Phase 2 safety management study.

# %%
query = "What does the investigational product treatment consist of"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The investigational product treatment consists of a single infusion of CAR transduced autologous T cells administered intravenously at a target dose of 2 x 10 anti-CD19 CAR T cells/kg. For subjects weighing greater than 100 kg, a maximum flat dose of 2 x 10 anti-CD19 CAR T cells will be administered. Under circumstances where subjects initially respond and subsequently relapse, subjects may be eligible for a second course of conditioning chemotherapy and axicabtagene ciloleucel.
# Retrieval entering 82f0bd41-61fe-4ce7-ad43-253f69c63950: TextNode
# Retrieving from object TextNode with query What does the investigational product treatment consist of
# Retrieval entering eb38e573-6a85-443e-a50a-0c5edd45fb60: TextNode
# Retrieving from object TextNode with query What does the investigational product treatment consist of
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# ...

# %% [markdown]
# This RAG is giving almost 80+ accuracy

# %% [markdown]
# ##WE CAN EVALUATE THE RAG USING BatchEvalRunner - Running Multiple Evaluations

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Response
from llama_index.llms.openai import OpenAI
from llama_index.core.evaluation import (
    FaithfulnessEvaluator,
    RelevancyEvaluator,
    CorrectnessEvaluator,
)
from llama_index.core.node_parser import SentenceSplitter
import pandas as pd

pd.set_option("display.max_colwidth", 0)

# %%
# gpt-4
gpt = OpenAI(temperature=0, model="gpt-3.5-turbo")

faithfulness_gpt = FaithfulnessEvaluator(llm=gpt)
relevancy_gpt = RelevancyEvaluator(llm=gpt)
correctness_gpt = CorrectnessEvaluator(llm=gpt)

# %%
# %pip install spacy datasets span-marker scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=c80e9e96da57db41e12718032e53d0787c9d23e09424dadcbd6e64b8aff23b68
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# ...

# %%
from llama_index.core.evaluation import DatasetGenerator

dataset_generator = DatasetGenerator.from_documents('/content/protocol.pdf', llm=llm)

qas = dataset_generator.generate_dataset_from_nodes(num=3)

# %%
from llama_index.core.evaluation import BatchEvalRunner

runner = BatchEvalRunner(
    {"faithfulness": faithfulness_gpt, "relevancy": relevancy_gpt},
    workers=8,
)

eval_results = await runner.aevaluate_queries(
    vector_index.as_query_engine(llm=llm), queries=qas.questions
)

# If we had ground-truth answers, we could also include the correctness evaluator like below.
# The correctness evaluator depends on additional kwargs, which are passed in as a dictionary.
# Each question is mapped to a set of kwargs
#

# runner = BatchEvalRunner(
#     {"correctness": correctness_gpt4},
#     workers=8,
# )

# eval_results = await runner.aevaluate_queries(
#     vector_index.as_query_engine(),
#     queries=qas.queries,
#     reference=[qr[1] for qr in qas.qr_pairs],
# )

# %%
print(eval_results.keys())

print(eval_results["faithfulness"][0].dict().keys())

print(eval_results["faithfulness"][0].passing)
print(eval_results["faithfulness"][0].response)
print(eval_results["faithfulness"][0].contexts)

# %%
print(len([qr for qr in qas.qr_pairs]))
